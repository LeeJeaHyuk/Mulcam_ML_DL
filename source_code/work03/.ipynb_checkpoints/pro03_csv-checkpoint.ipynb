# %% [markdown]
# csv 파일을 가져올 때 나올 수 있는 error
# 1. 구분자 에러
#    -  a b c d -> a, b, c, d
# 2. 값의 ","" , '''
#    - 'a','b','c','d' -> 값의 ""을 없앤 상태로 재저장
# 3. '100', '100' -> int인 경우
#
# 각각의 type을 반드시 확인해야 한다

# %%
# 파이썬 모듈을 이용한 csv 파일 처리
# csv를 python으로 가져오는 작업을 하는 법
import csv

# %%
# dir(csv)

# 1) csv파일 읽기
file = csv.reader('c:\\ds_work\\data\\emp.csv') 

#2) 객체로 출력되는 것을 확인
file
type(file)
# Out:
# _csv.reader

# %%
#3) 전체 내용 출력 _파일의 내용을 한 행씩 리스트 객체에 담아서 출력
for emp_list in file :
    print(f"{emp_list[1]}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       1 #3) 전체 내용 출력 _파일의 내용을 한 행씩 리스트 객체에 담아서 출력
#       2 for emp_list in file :
# ----> 3     print(f"{emp_list[1]}")
#
# IndexError: list index out of range
